# %%
def conditional_probability(prob_a_and_b,prob_b):
    """
    :param prob_a_and_b:
    :param prob_b:
    :return:
    """
    return prob_a_and_b/prob_b

prob_a=0.6
prob_b=0.4
prob_a_and_b=0.3

prob_a_given_b= conditional_probability(prob_a_and_b,prob_b)
print("우유를 산 경우에 빵을 살 확률:",prob_a_given_b)
# Out:
# 우유를 산 경우에 빵을 살 확률: 0.7499999999999999

# %%
colors = ['#348ABD', "#A60628"]
prior = [1/25., 24/25.]
posterior = [0.158, 1-0.158]

plt.bar([0, 0.7], prior, alpha=0.7,wldth=0.25, color=colors[0], label='사전확률',lw=3,edgecolor='#34BABD')
plt.bar([0+0.25, 0.7+0.25], posterior, alpha=0.7,width=0.25, color=colors[1], label='사후확률',lw=3, edgecolor='#A60628')

plt.xticks([0.12, 0.82], ['가수', '직장인'])
plt.title('철수의직업에대한사전확률과사후확률')
plt.ylabel('확률')
plt.legend(loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 prior = [1/25., 24/25.]
#       3 posterior = [0.158, 1-0.158]
# ----> 5 plt.bar([0, 0.7], prior, alpha=0.7,wldth=0.25, color=colors[0], label='사전확률',lw=3,edgecolor='#34BABD')
#       6 plt.bar([0+0.25, 0.7+0.25], posterior, alpha=0.7,width=0.25, color=colors[1], label='사후확률',lw=3, edgecolor='#A60628')
#       8 plt.xticks([0.12, 0.82], ['가수', '직장인'])
#
# NameError: name 'plt' is not defined
